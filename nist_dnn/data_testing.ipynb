# %%
import experiment
import pandas as pd

exp = experiment.Experiment("../experiment_configs/config_1.py")
data = exp.process_data()

# data.to_csv("dataset.csv", index=False)
# Out:
# [INFO] Loaded data from /Users/rishabhgoel/Projects/RandomnessTestingSave/binary_data/Qnumbers.bin
# [INFO] Split data into 20000 chunks of 1024 bits
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 0, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 1, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 1, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 0, 0, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 1, 1, 1, 0, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 0, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 1, 1, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 0, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 0, 1, 1, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 0, 1, 1, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 0, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 0, 1, 0, 0, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 0, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 0, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 0, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 0, 1, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [1, 1, 1, 1, 1, 1, 1, 0, 0]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 0, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 0, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 0, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 0, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 0, 1, 1, 1, 1, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 0, 0, 1, 1]
# No free spaces to fit template [0, 0, 1, 0, 0, 0, 0, 1, 1]
# ...
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
#      Statistical Testing Complete!!!!!!!!!!!!
#
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# igamc: UNDERFLOW
# Counter({'111111110': 37940, '110011000': 18590, '100010000': 16404, '110011100': 12895, '000010010': 10688, '110011110': 10470, '000010000': 9966, '000010110': 5162, '110011010': 2218, '100011000': 2120, '110111110': 1703, '111111100': 1487, '100010100': 1193, '000010100': 1114, '111011110': 1072, '010010010': 1011, '010010110': 826, '000110110': 536, '111111010': 438, '011110110': 334, '000110100': 330, '101111110': 316, '110111010': 313, '100011100': 283, '010011010': 250, '001010110': 230, '110111100': 221, '011010110': 218, '010011110': 197, '001110110': 165, '110010100': 118, '111110110': 110, '110010110': 101, '011111110': 90, '010110110': 86, '000110010': 66, '110010000': 61, '111011010': 54, '010110010': 52, '011011110': 48, '010010000': 46, '010010100': 42, '101111100': 40, '001110100': 31, '010111110': 27, '000110000': 23, '111111000': 20, '011110100': 19, '101110110': 18, '111011100': 18, '010111010': 16, '111010110': 16, '001111110': 15, '100011110': 14, '101011110': 13, '110010010': 13, '011111100': 13, '001010100': 11, '011010010': 10, '001011110': 9, '111110100': 8, '010011100': 8, '011010100': 8, '100111110': 8, '110111000': 8, '010110100': 7, '110110110': 7, '001010010': 5, '110110010': 4, '110110100': 4, '011110010': 4, '101010110': 4, '100110110': 4, '100010110': 4, '010110000': 3, '100110100': 3, '011011010': 3, '100110000': 2, '100111100': 2, '001110010': 2, '000011100': 1, '111110010': 1, '101111000': 1, '100110010': 1, '111011000': 1, '101010100': 1, '101010010': 1, '010111100': 1, '000111100': 1, '111010100': 1, '010011000': 1, '001011010': 1})
